# %%
from pyemsi import Plotter
import pyvista as pv
file_path = r"C:\Users\eskan\OneDrive\Documents\Github\pyemsi\.pyemsi\output.pvd"
plt = Plotter(notebook=True, backend="static").set_file(file_path)
print(plt.mesh[0].array_names)
plt.reader.set_active_time_point(-1)
plt.plotter.view_xy()
plt.set_scalar("B-Mag (T)", mode="element", cell2point=False, edge_opacity=0.0).show()

plt2 = Plotter(notebook=True, backend="static").set_file(file_path)
plt2.plotter.view_xy()
plt2.set_scalar("Flux (A/m)", mode="node").show()
# Out:
# ['B-Vec (T)', 'B-Mag (T)', 'Flux (A/m)', 'J-Vec (A/m^2)', 'J-Mag (A/m^2)', 'Loss (W/m^3)', 'F Nodal-Vec (N/m^3)', 'F Nodal-Mag (N/m^3)', 'vtkOriginalPointIds', 'PropertyID', 'B-Vec (T)', 'B-Mag (T)', 'J-Vec (A/m^2)', 'J-Mag (A/m^2)', 'Loss (W/m^3)', 'F Nodal-Vec (N/m^3)', 'F Nodal-Mag (N/m^3)', 'vtkOriginalCellIds']
# <PIL.Image.Image image mode=RGB size=1024x768>
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
plt = Plotter(notebook=True, backend="html")
mesh = pv.Sphere()
plt.plotter.add_mesh(mesh)
plt.plotter.show()
# Out:
# EmbeddableWidget(value='<iframe srcdoc="<!DOCTYPE html>\n<html>\n  <head>\n    <meta http-equiv=&quot;Content-…
